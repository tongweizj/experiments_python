# %% [markdown]
# df.eval(): Does calculations.
#
# df.query(): Finds rows.
#
# df.groupby(): Builds groups of rows.

# %%
import pandas as pd
df = pd.read_csv('right-triangles.csv')
df
# Out:
#     color  base  height
# 0     red    15      18
# 1   green    30      10
# 2  yellow     8       5
# 3  orange    12      12
# 4    blue    22      13
# 5    blue    24      13
# 6  yellow    18      25
# 7    blue     2       1

# %%
df['area'] = df.eval('0.5 * base * height')
df # display it
# Out:
#     color  base  height   area
# 0     red    15      18  135.0
# 1   green    30      10  150.0
# 2  yellow     8       5   20.0
# 3  orange    12      12   72.0
# 4    blue    22      13  143.0
# 5    blue    24      13  156.0
# 6  yellow    18      25  225.0
# 7    blue     2       1    1.0

# %%
df2 = df['color'].value_counts()
df2
# Out:
# color
# blue      3
# yellow    2
# red       1
# green     1
# orange    1
# Name: count, dtype: int64

# %%
df2_counts = df2.sort_index()
df2_counts
# Out:
# color
# blue      3
# green     1
# orange    1
# red       1
# yellow    2
# Name: count, dtype: int64

# %%
df2_counts.plot.bar()
# Out:
# <Axes: xlabel='color'>

# %%
df2_counts.head(2)
# Out:
# color
# blue     3
# green    1
# Name: count, dtype: int64
